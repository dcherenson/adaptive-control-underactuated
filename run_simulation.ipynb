# %%
using Revise
includet("vtol.jl")
includet("adaptation.jl")
includet("high_level_control.jl")
includet("control_allocation.jl")
includet("simulation.jl")
import .ControlAllocation: n_x, n_u, n_λ, n_W
import .HighLevelController: ref_pose, ref_velocity, RefTrajParams
import .Simulation: SimulationData, SimulationParams, scenario_high_level_params, dudt!, adaptive_control_allocator!, cascaded_pid_allocator!
import .VTOL: VTOLParams
using LinearAlgebra, Plots, DifferentialEquations, ForwardDiff, StaticArrays, DiffEqCallbacks

# %%
x0 = @MVector zeros(n_x);

scenario = :landing  # :landing | :takeoff | :sinusoidal_transition
controller_mode = :adaptive  # :adaptive | :pid_benchmark

sim = SimulationParams(high_level=scenario_high_level_params(scenario))
traj = sim.high_level.ref_traj

r0 = ref_pose(sim.t0, traj)
rdot0 = ref_velocity(sim.t0, traj)
x0[1] = 0.0 + r0[1]  # Initial position x
x0[4] = 0.0 + rdot0[1]  # Initial velocity x
x0[2] = 1.0 + r0[2]  # Initial position y
x0[5] = 0.0 + rdot0[2]  # Initial velocity y
x0[3] = r0[3]+deg2rad(4.0)  # Initial pitch angle

xhat0 = copy(x0)

λ = @MVector zeros(n_λ);
u = @MVector[0.01, 0.01, 0.4, -0.3, x0[3]];
vtol = VTOLParams()
W_true = @SVector[vtol.CDδ, vtol.CDα, vtol.CDt, vtol.CLδ, vtol.CLα, vtol.Cmδ, vtol.Cmα, 1.0, 0.0]
W = MVector{n_W}(W_true*1.5)

allocator_cb = controller_mode == :adaptive ? adaptive_control_allocator! : cascaded_pid_allocator!
cb = PeriodicCallback(allocator_cb, sim.dt; initial_affect=true)

data = SimulationData(u=u, λ=λ, W=W, xhat=xhat0, params=sim)

prob = ODEProblem(dudt!, x0, (sim.t0, sim.t_final), data)

@time sol = solve(prob, Tsit5(), callback = cb)
# Out:
#  33.820512 seconds (54.84 M allocations: 2.743 GiB, 5.52% gc time, 98.85% compilation time)
# retcode: Success
# Interpolation: specialized 4th order "free" interpolation
# t: 6002-element Vector{Float64}:
#   0.0
#   0.0
#   0.00122075947806127
#   0.01
#   0.01
#   0.02
#   0.02
#   0.03
#   0.03
#   0.04
#   ⋮
#  29.96
#  29.96
#  29.97
#  29.97
#  29.98
#  29.98
#  29.990000000000002
#  29.990000000000002
#  30.0
# u: 6002-element Vector{MVector{6, Float64}}:
#  [-260.0111268042049, 101.00556340210242, 0.06981317007977318, 19.985219285847666, 0.009244824443644162, 0.0]
#  [-260.0111268042049, 101.00556340210242, 0.06981317007977318, 19.985219285847666, 0.009244824443644162, 0.0]
#  [-259.9867296107717, 101.00557276333191, 0.06981448695828826, 19.985297445606047, 0.006094369965650932, 0.002153260481800216]
#  [-259.811271286291, 101.0055281893126, 0.06989905291709875, 19.98589940405218, -0.016116445640281248, 0.01689370224748194]
#  [-259.811271286291, 101.0055281893126, 0.06989905291709875, 19.98589940405218, -0.016116445640281248, 0.01689370224748194]
#  [-259.61141029774166, 101.00524626233542, 0.07011660525987005, 19.986313082190282, -0.0400971272753626, 0.026384513824628097]
#  [-259.61141029774166, 101.00524626233542, 0.07011660525987005, 19.986313082190282, -0.0400971272753626, 0.026384513824628097]
#  [-259.41154580947284, 101.00473032582053, 0.07041098283042323, 19.98659905885484, -0.06291925541936486, 0.03228460532704655]
#  [-259.41154580947284, 101.00473032582053, 0.07041098283042323, 19.98659905885484, -0.06291925541936486, 0.03228460532704655]
#  [-259.21167887937736, 101.00399130488776, 0.07075684599375655, 19.98680118117689, -0.08471531482390689, 0.036693234520059376]
#  ⋮
#  [0.10296166874701289, 79.79001573561428, 0.19606657743675077, -0.032066258905748136, -0.7545771196538527, -5.454508879034252e-6]
#  [0.10296166874701289, 79.79001573561428, 0.19606657743675077, -0.032066258905748136, -0.7545771196538527, -5.454508879034252e-6]
#  [0.10264142412746644, 79.7824700339319, 0.19606652012331524, -0.03198266274688673, -0.7545632200026635, -6.0215491770366645e-6]
#  [0.10264142412746644, 79.7824700339319, 0.19606652012331524, -0.03198266274688673, -0.7545632200026635, -6.0215491770366645e-6]
#  [0.1023220149572727, 79.77492447104689, 0.19606645718119284, -0.03189916894397735, -0.7545493601744805, -6.580228613426601e-6]
#  [0.1023220149572727, 79.77492447104689, 0.19606645718119284, -0.03189916894397735, -0.7545493601744805, -6.580228613426601e-6]
#  [0.10200344020523962, 79.76737904656153, 0.19606638869338838, -0.03181577902493403, -0.7545355400637447, -7.130667715709838e-6]
#  [0.10200344020523962, 79.76737904656153, 0.19606638869338838, -0.03181577902493403, -0.7545355400637447, -7.130667715709838e-6]
#  [0.10168569882503076, 79.75983376007919, 0.19606631474171005, -0.0317324944906943, -0.7545217595650562, -7.672985299065643e-6]

# %%
t_vec = data.t_hist
τ = zeros(n_λ,length(t_vec))

L_vec = zeros(length(t_vec))

J_vec = zeros(length(t_vec))

k_vec = zeros(n_λ,length(t_vec))

FOO_vec = zeros(n_u+n_λ, length(t_vec))

M_aero_vec = zeros(length(t_vec))
α_vec = zeros(length(t_vec))
e_s_vec = zeros(6, length(t_vec))
norm_e_s_vec = zeros(length(t_vec))

uλWdot_vec = zeros(n_u+n_λ+n_W, length(t_vec)-1)

Lift_vec = zeros(length(t_vec))

lyapunov_vec = zeros(length(t_vec))
Vdot_vec = zeros(length(t_vec))
# Γ_ϵ = Diagonal([10.0, 10.0, 10.0, 10.0, 100.0, 100.0])

sliding_vec = zeros(n_λ, length(t_vec))
du = zeros(length(sol(0)))

u_hist = zeros(n_u, length(t_vec))
λ_hist = zeros(n_λ, length(t_vec))
W_hist = zeros(n_W, length(t_vec))


norm_W_vec = zeros(length(t_vec))

vel_mag_vec = zeros(length(t_vec))

d2Ldxdudλ_vel_vec = zeros(length(t_vec))

for (j, t) in enumerate(t_vec)
    x = sol(t)
    u = data.u_hist[j]
    λ = data.λ_hist[j]
    W = data.W_hist[j]
    xhat = data.xhat_hist[j]
    u_hist[:,j] = u[1:end]
    λ_hist[:,j] = λ[1:end]
    W_hist[:,j] = W[1:end]
    norm_W_vec[j] = norm(W)
    vel_mag_vec[j] = sqrt(x[4]^2 + x[5]^2)
    e_s_vec[:,j] = x - xhat
    norm_e_s_vec[j] = norm(e_s_vec[:,j])

    if controller_mode == :adaptive
        FOO_vec[:,j] = [ControlAllocation.dL_du(t,x,u,λ,W,xhat, data.params); ControlAllocation.constraint(t,x,u,W,xhat, data.params)]
    end
end

# %%
# include("animation.jl")
# animate_vtol(t_vec, sol, u_hist, t-> ref_pose(t, traj); fps=15, filename="vtol_landing.gif")

# %%
x_pos_vec = [sol(t)[1] for t in t_vec]
z_pos_vec = [sol(t)[2] for t in t_vec]
plot(x_pos_vec, z_pos_vec, xlabel="p_x [m]", ylabel="p_z [m]",
     title="VTOL Trajectory", label="Trajectory",
      legend=false, line_z = vel_mag_vec, colormap=:RdBu, linewidth=4, colorbar=:bottom, colorbar_title="Velocity [m/s]")
rx_vec = [ref_pose(t, traj)[1] for t in t_vec]
ry_vec = [ref_pose(t, traj)[2] for t in t_vec]
# plot!(rx_vec, ry_vec, label="Reference Trajectory", color=:black, linestyle=:dash, linewidth=4)
pitches = []
for t_plot in sim.t0:5.0:sim.t_final
    x_ref = ref_pose(t_plot, traj)
    scatter!([x_ref[1]], [x_ref[2]], color=:red, label="")
    push!(pitches, sol(t_plot)[3])
end
plot!(aspect_ratio=5, xtickfontsize=12, ytickfontsize=12, size=(1200,400))

# Plots.savefig("paper/trajectory_tracking.svg")
# pitches*rad2deg(1)

# %%
plot(t_vec, u_hist',label=["front [% of max rpm]" "rear [% of max rpm]" "pusher [% of max rpm]" "elevator [rad]" "pitch cmd [rad]"],
     xlabel="Time [s]", ylabel="Control Inputs",
       ylims = (-1.0,1.0),linewidth = 2,legend=true, xtickfontsize=12, ytickfontsize=12)

# %%
using LaTeXStrings

rear_prop_degrade = [VTOL.rear_prop_degradation(sol(t), u_hist[:,i])/u_hist[3,i]^2 for (i,t) in enumerate(t_vec)]
labels = [L"C_{D_e}", L"C_{D_\alpha}", L"C_{D_t}", L"C_{L_e}", L"C_{L_\alpha}", L"C_{M_e}", L"C_{M_\alpha}", L"C_{M_\omega}", L"C_{pr}"]
palette = distinguishable_colors(length(labels))
plot()
for i in 1:n_W-1
    plot!(t_vec, abs.(W_hist[i,:] .- W_true[i]), label=labels[i], linewidth=2, color=palette[i])
end
plot!(t_vec, abs.(W_hist[end,:] - rear_prop_degrade), label=labels[end], linewidth=2, color=palette[end])
plot!(legend=true, legend_columns=3,ylims=(0,3), xtickfontsize=14, ytickfontsize=14, legendfontsize=14, xlabel="Time [s]", ylabel="Parameter Error")

# %%
tracking_error_x = [sol(t)[1] - ref_pose(t, traj)[1] for t in t_vec]
tracking_error_y = [sol(t)[2] - ref_pose(t, traj)[2] for t in t_vec]
tracking_error_pitch = [sol(t)[3] for t in t_vec] - u_hist[5,:] # pitch command
palette = distinguishable_colors(5)[3:end]
plot(t_vec, tracking_error_x, 
xlabel="Time [s]", ylabel="Tracking Error [m]", title="Tracking Error",
 color = palette[1], label ="p_x err", ylim=(-3.5,3.5), legend=:topleft, linewidth=4, grid=true)
plot!(t_vec, tracking_error_y, color = palette[2], label="p_z err", linewidth=4)
plot!(twinx(), t_vec, 180/pi*tracking_error_pitch, color = palette[3], label="pitch err", ylim=(-3.5,3.5), grid=true, legend=:topright, linewidth=4, ylabel="Tracking Error [deg]")

# %%
plot(t_vec, FOO_vec', label=["∂L/∂u₁" "∂L/∂u₂" "∂L/∂u₃" "∂L/∂u₄" "∂L/∂u₅" "∂L/∂λ₁" "∂L/∂λ₂" "∂L/∂λ₃"],
     xlabel="Time [s]", ylabel="Gradient of Lagrangian",
     title="Gradient of Lagrangian Evolution", ylim=(-1, 1), linewidth=2)

# %%
plot(t_vec, norm_e_s_vec, xlabel="Time [s]", ylabel="||e_s||",
     title="State Estimation Error Norm", ylim=(0, 2.0),legend=false, linewidth=2)

# %%
# Benchmark helper: run one scenario with either adaptive or non-adaptive PID inner loop
function run_controller_case(controller_mode::Symbol, scenario::Symbol)
    x0 = @MVector zeros(n_x)

    sim = SimulationParams(high_level=scenario_high_level_params(scenario))
    traj = sim.high_level.ref_traj

    r0 = ref_pose(sim.t0, traj)
    rdot0 = ref_velocity(sim.t0, traj)
    x0[1] = 0.0 + r0[1]
    x0[4] = 0.0 + rdot0[1]
    x0[2] = 1.0 + r0[2]
    x0[5] = 0.0 + rdot0[2]
    x0[3] = r0[3] + deg2rad(4.0)

    xhat0 = copy(x0)

    λ = @MVector zeros(n_λ)
    u = @MVector[0.01, 0.01, 0.4, -0.3, x0[3]]
    vtol = VTOLParams()
    W_true = @SVector[vtol.CDδ, vtol.CDα, vtol.CDt, vtol.CLδ, vtol.CLα, vtol.Cmδ, vtol.Cmα, 1.0, 0.0]
    W = MVector{n_W}(W_true * 1.5)

    allocator_cb = controller_mode == :adaptive ? adaptive_control_allocator! : cascaded_pid_allocator!
    cb = PeriodicCallback(allocator_cb, sim.dt; initial_affect=true)

    data = SimulationData(u=copy(u), λ=copy(λ), W=copy(W), xhat=copy(xhat0), params=sim)
    prob = ODEProblem(dudt!, copy(x0), (sim.t0, sim.t_final), data)
    sol = solve(prob, Tsit5(), callback=cb)

    t_vec = data.t_hist
    tracking_error_x = [sol(t)[1] - ref_pose(t, traj)[1] for t in t_vec]
    tracking_error_z = [sol(t)[2] - ref_pose(t, traj)[2] for t in t_vec]
    tracking_error_pitch = [sol(t)[3] - data.u_hist[i][5] for (i, t) in enumerate(t_vec)]

    return (
        mode=controller_mode,
        scenario=scenario,
        sim=sim,
        traj=traj,
        sol=sol,
        data=data,
        t_vec=t_vec,
        err_x=tracking_error_x,
        err_z=tracking_error_z,
        err_pitch=tracking_error_pitch,
    )
end

benchmark_scenario = :landing  # :landing | :takeoff | :sinusoidal_transition
adaptive_case = run_controller_case(:adaptive, benchmark_scenario)
pid_case = run_controller_case(:pid_benchmark, benchmark_scenario)
# Out:
# (mode = :pid_benchmark, scenario = :landing, sim = SimulationParams(VTOLParams(10.0, 1.0, 0.5, 100.0, 50.0, 1.225, 0.5, 0.2, -0.99, -2.74, 0.0135, 0.043, 0.03, 0.0135, 0.1, 0.23, 5.61, 0.13, 7.95, -38.21, 0.8, 0.2617993877991494, 50.0), Main.ControlAllocation.ControlAllocationParams((-0.6108652381980153, 0.6108652381980153), (-0.3490658503988659, 0.3490658503988659), 0.01, [10.0, 10.0, 1.0, 0.1, 50.0], 50.0), Main.HighLevelController.HighLevelParams(0.5, 2.0, 0.2, Main.HighLevelController.LandingTrajParams(3.0, 20.0, 100.0, -1.0, -0.75, 0.0, 0.2617993877991494)), Main.Adaptation.AdaptationParams(5.0, 5.0, 100.0, 0.1), Main.Simulation.CascadedPIDParams(Main.Simulation.PIDGains(6.228845113923736, 0.7627180213961051, 1.610646975999857, 0.21235433329717518, 2.607409204103294), Main.Simulation.PIDGains(4.140902579583811, 0.21548281390889493, 0.19465227221502693, 0.12829925812585746, 0.996981866672961), Main.Simulation.PIDGains(12.540123852871549, 0.6534211743132547, 0.12632870115792455, 0.30452218869016134, 46.14207499618037), Main.Simulation.PIDGains(2.283473956525624, 0.7075176757989048, 0.04184332007633861, 0.40835642307919157, 60.0), 8.519220520703417, 10.519220520703417, -0.014645461382071314, 0.4, -0.12, -0.02, [2.0, 2.0, 2.0, 4.0, 4.0], 1.95), 0.01, 0.0, 30.0), traj = Main.HighLevelController.LandingTrajParams(3.0, 20.0, 100.0, -1.0, -0.75, 0.0, 0.2617993877991494), sol = ODESolution{Float64, 2, Vector{MVector{6, Float64}}, Nothing, Nothing, Vector{Float64}, Vector{Vector{MVector{6, Float64}}}, Nothing, ODEProblem{MVector{6, Float64}, Tuple{Float64, Float64}, true, SimulationData{Float64}, ODEFunction{true, SciMLBase.AutoSpecialize, typeof(dudt!), UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing, Nothing, Nothing}, Base.Pairs{Symbol, Union{}, Tuple{}, @NamedTuple{}}, SciMLBase.StandardODEProblem}, Tsit5{typeof(OrdinaryDiffEqCore.trivial_limiter!), typeof(OrdinaryDiffEqCore.trivial_limiter!), Static.False}, OrdinaryDiffEqCore.InterpolationData{ODEFunction{true, SciMLBase.AutoSpecialize, typeof(dudt!), UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing, Nothing, Nothing}, Vector{MVector{6, Float64}}, Vector{Float64}, Vector{Vector{MVector{6, Float64}}}, Nothing, OrdinaryDiffEqTsit5.Tsit5Cache{MVector{6, Float64}, MVector{6, Float64}, MVector{6, Float64}, typeof(OrdinaryDiffEqCore.trivial_limiter!), typeof(OrdinaryDiffEqCore.trivial_limiter!), Static.False}, Nothing}, SciMLBase.DEStats, Nothing, Nothing, Nothing, Nothing}(MVector{6, Float64}[[-260.0111268042049, 101.00556340210242, 0.06981317007977318, 19.985219285847666, 0.009244824443644162, 0.0], [-260.0111268042049, 101.00556340210242, 0.06981317007977318, 19.985219285847666, 0.009244824443644162, 0.0], [-259.9892542903452, 101.00557197420912, 0.06981435374187982, 19.984830011651795, 0.006421878932984123, 0.0021594385072002866], [-259.81825394902415, 101.00553373338063, 0.06990282587575064, 19.98182553758841, -0.015235092313285447, 0.01829799981949118], [-259.811292263239, 101.0055282745978, 0.06990931057668341, 19.98170467475319, -0.016100815391065355, 0.01892703480810205], [-259.811292263239, 101.0055282745978, 0.06990931057668341, 19.98170467475319, -0.016100815391065355, 0.01892703480810205], [-259.74168058894776, 101.00545771926204, 0.06998025722991437, 19.97885190859958, -0.02438214810139991, 0.021773109475696148], [-259.6115160784071, 101.00524918073742, 0.07013838075542007, 19.973548775215914, -0.03955818175905078, 0.026668876471633098], [-259.6115160784071, 101.00524918073742, 0.07013838075542007, 19.973548775215914, -0.03955818175905078, 0.026668876471633098], [-259.41184009614756, 101.00474568599357, 0.07039136844628872, 19.961665008298887, -0.06100275467142033, 0.023803363397663223]  …  [-180.66210357170783, -431.67146 ...

# %%
# Side-by-side tracking error comparison: adaptive vs PID benchmark
p_x = plot(
    adaptive_case.t_vec, adaptive_case.err_x,
    label="adaptive", linewidth=3, color=:blue,
    xlabel="Time [s]", ylabel="p_x error [m]", title="Tracking Error in p_x",
    grid=true,
 )
plot!(p_x, pid_case.t_vec, pid_case.err_x, label="pid benchmark", linewidth=3, color=:red, linestyle=:dash)

p_z = plot(
    adaptive_case.t_vec, adaptive_case.err_z,
    label="adaptive", linewidth=3, color=:blue,
    xlabel="Time [s]", ylabel="p_z error [m]", title="Tracking Error in p_z",
    grid=true,
 )
plot!(p_z, pid_case.t_vec, pid_case.err_z, label="pid benchmark", linewidth=3, color=:red, linestyle=:dash)

p_theta = plot(
    adaptive_case.t_vec, 180/pi .* adaptive_case.err_pitch,
    label="adaptive", linewidth=3, color=:blue,
    xlabel="Time [s]", ylabel="pitch error [deg]", title="Tracking Error in Pitch",
    grid=true,
 )
plot!(p_theta, pid_case.t_vec, 180/pi .* pid_case.err_pitch, label="pid benchmark", linewidth=3, color=:red, linestyle=:dash)

plot(p_x, p_z, p_theta, layout=(3, 1), size=(1200, 900))
