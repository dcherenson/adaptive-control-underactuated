# %%
using Revise
includet("vtol.jl")
includet("adaptation.jl")
includet("high_level_control.jl")
includet("control_allocation.jl")
includet("simulation.jl")
import .ControlAllocation: n_x, n_u, n_λ, n_W
import .HighLevelController: ref_pose, ref_velocity, high_level_control, RefTrajParams
import .Simulation: SimulationData, SimulationParams, scenario_high_level_params, dudt!, adaptive_control_allocator!, cascaded_pid_allocator!
import .VTOL: VTOLParams
using LinearAlgebra, Plots, DifferentialEquations, ForwardDiff, StaticArrays, DiffEqCallbacks

# %%
Revise.revise()  # Ensure all changes are picked up

# %%
x0 = @MVector zeros(n_x);

scenario = :takeoff  # :landing | :takeoff | :sinusoidal_transition
controller_mode = :adaptive  # :adaptive | :pid_benchmark

sim = SimulationParams(high_level=scenario_high_level_params(scenario))
traj = sim.high_level.ref_traj

r0 = ref_pose(sim.t0, traj)
rdot0 = ref_velocity(sim.t0, traj)
x0[1] = 0.0 + r0[1]  # Initial position x
x0[4] = 0.01 + rdot0[1]  # Initial velocity x
x0[2] = 1.0 + r0[2]  # Initial position y
x0[5] = 0.0 + rdot0[2]  # Initial velocity y
x0[3] = r0[3]+deg2rad(0.0)  # Initial pitch angle

xhat0 = copy(x0)

λ = @MVector zeros(n_λ);
u = @MVector[0.7, 0.7, 0.1, -0.0, x0[3]];
vtol = VTOLParams()
W_true = @SVector[vtol.CDδ, vtol.CDα, vtol.CDt, vtol.CLδ, vtol.CLα, vtol.Cmδ, vtol.Cmα, 1.0, 0.0]
W = MVector{n_W}(W_true*1.0)

# Keep clean initial copies for repeatable benchmark/comparison runs.
x0_initial = copy(x0)
u_initial = copy(u)
λ_initial = copy(λ)
W_initial = copy(W)
xhat0_initial = copy(xhat0)

allocator_cb = controller_mode == :adaptive ? adaptive_control_allocator! : cascaded_pid_allocator!
cb = PeriodicCallback(allocator_cb, sim.dt; initial_affect=true)

data = SimulationData(u=copy(u_initial), λ=copy(λ_initial), W=copy(W_initial), xhat=copy(xhat0_initial), params=sim)

prob = ODEProblem(dudt!, copy(x0_initial), (sim.t0, sim.t_final), data)

sol = solve(prob, Tsit5(), callback = cb)
# Out:
# retcode: Success
# Interpolation: specialized 4th order "free" interpolation
# t: 6002-element Vector{Float64}:
#   0.0
#   0.0
#   0.00562710668025536
#   0.01
#   0.01
#   0.02
#   0.02
#   0.03
#   0.03
#   0.04
#   ⋮
#  29.96
#  29.96
#  29.97
#  29.97
#  29.98
#  29.98
#  29.990000000000002
#  29.990000000000002
#  30.0
# u: 6002-element Vector{MVector{6, Float64}}:
#  [0.04470109575829409, 101.0, 0.017453292519943295, -0.000657002463958287, 0.0, 0.0]
#  [0.04470109575829409, 101.0, 0.017453292519943295, -0.000657002463958287, 0.0, 0.0]
#  [0.044695503803663494, 100.99999563271777, 0.017455145735013944, -0.001330520233823224, -0.001552230540974218, 0.000658675982305896]
#  [0.044688540980122954, 100.99998620755787, 0.017459145234968897, -0.0018540460083149384, -0.0027584901144148263, 0.0011705487836017317]
#  [0.044688540980122954, 100.99998620755787, 0.017459145234968897, -0.0018540460083149384, -0.0027584901144148263, 0.0011705487836017317]
# ...

# %%
t_vec = data.t_hist
τ = zeros(n_λ,length(t_vec))

L_vec = zeros(length(t_vec))

J_vec = zeros(length(t_vec))

k_vec = zeros(n_λ,length(t_vec))

FOO_vec = zeros(n_u+n_λ, length(t_vec))

cmd_hist = zeros(n_λ, length(t_vec))

achieved_accel_hist = zeros(2, length(t_vec))

M_aero_vec = zeros(length(t_vec))
α_vec = zeros(length(t_vec))
e_s_vec = zeros(6, length(t_vec))
norm_e_s_vec = zeros(length(t_vec))

uλWdot_vec = zeros(n_u+n_λ+n_W, length(t_vec)-1)

Lift_vec = zeros(length(t_vec))

lyapunov_vec = zeros(length(t_vec))
Vdot_vec = zeros(length(t_vec))
# Γ_ϵ = Diagonal([10.0, 10.0, 10.0, 10.0, 100.0, 100.0])

sliding_vec = zeros(n_λ, length(t_vec))
du = zeros(length(sol(0)))

u_hist = zeros(n_u, length(t_vec))
λ_hist = zeros(n_λ, length(t_vec))
W_hist = zeros(n_W, length(t_vec))


norm_W_vec = zeros(length(t_vec))

vel_mag_vec = zeros(length(t_vec))

d2Ldxdudλ_vel_vec = zeros(length(t_vec))

for (j, t) in enumerate(t_vec)
    x = t <= sol.t[end] ? sol(t) : fill(NaN, n_x)
    u = data.u_hist[j]
    λ = data.λ_hist[j]
    W = data.W_hist[j]
    xhat = data.xhat_hist[j]

    if all(isfinite, x) && all(isfinite, u) && all(isfinite, xhat)
        cmd_hist[:,j] = high_level_control(t, x, u, xhat, data.params.high_level, data.params.adaptation)
    else
        cmd_hist[:,j] .= NaN
    end

    if all(isfinite, x) && all(isfinite, u)

        achieved_accel_hist[:,j] = VTOL.dynamics_sim(x, u, data.params.vtol)[4:5]

    else

        achieved_accel_hist[:,j] .= NaN

    end
    u_hist[:,j] = u[1:end]
    λ_hist[:,j] = λ[1:end]
    W_hist[:,j] = W[1:end]
    norm_W_vec[j] = norm(W)
    vel_mag_vec[j] = sqrt(x[4]^2 + x[5]^2)
    e_s_vec[:,j] = x - xhat
    norm_e_s_vec[j] = norm(e_s_vec[:,j])

    if controller_mode == :adaptive && all(isfinite, x) && all(isfinite, u) && all(isfinite, λ) && all(isfinite, W) && all(isfinite, xhat)

        FOO_vec[:,j] = [ControlAllocation.dL_du(t,x,u,λ,W,xhat, data.params); ControlAllocation.constraint(t,x,u,W,xhat, data.params)]

    elseif controller_mode == :adaptive

        FOO_vec[:,j] .= NaN

    end
end

# %%
include("animation.jl")
animate_vtol(t_vec, sol, u_hist, t-> ref_pose(t, traj); fps=15, filename="vtol_landing.gif")

# %%
x_pos_vec = [sol(t)[1] for t in t_vec]
z_pos_vec = [sol(t)[2] for t in t_vec]
plot(x_pos_vec, z_pos_vec, xlabel="p_x [m]", ylabel="p_z [m]",
     title="VTOL Trajectory", label="Trajectory",
      legend=false, line_z = vel_mag_vec, colormap=:RdBu, linewidth=4, colorbar=:bottom, colorbar_title="Velocity [m/s]")
rx_vec = [ref_pose(t, traj)[1] for t in t_vec]
ry_vec = [ref_pose(t, traj)[2] for t in t_vec]
# plot!(rx_vec, ry_vec, label="Reference Trajectory", color=:black, linestyle=:dash, linewidth=4)
pitches = []
for t_plot in sim.t0:5.0:sim.t_final
    x_ref = ref_pose(t_plot, traj)
    scatter!([x_ref[1]], [x_ref[2]], color=:red, label="")
    push!(pitches, sol(t_plot)[3])
end
plot!(aspect_ratio=5, xtickfontsize=12, ytickfontsize=12, size=(1200,400))

# Plots.savefig("paper/trajectory_tracking.svg")
# pitches*rad2deg(1)

# %%
plot(t_vec, u_hist',label=["front [% of max rpm]" "rear [% of max rpm]" "pusher [% of max rpm]" "elevator [rad]" "pitch cmd [rad]"],
     xlabel="Time [s]", ylabel="Control Inputs",
       ylims = (-1.0,1.0),linewidth = 2,legend=true, xtickfontsize=12, ytickfontsize=12)

# %%
# High-level commanded and achieved accelerations
p_cmd_x = plot(
    t_vec,
    cmd_hist[1, :],
    label="a_x cmd",
    xlabel="Time [s]",
    ylabel="a_x [m/s^2]",
    title="x Acceleration: Command vs Achieved",
    linewidth=3,
    color=:blue,
    grid=true,
)
plot!(p_cmd_x, t_vec, achieved_accel_hist[1, :], label="a_x achieved", linewidth=2.5, color=:orange, linestyle=:dash)
hline!(p_cmd_x, [-2.0, 3.0], label=false, linestyle=:dot, color=:black, linewidth=1.5)

p_cmd_z = plot(
    t_vec,
    cmd_hist[2, :],
    label="a_z cmd",
    xlabel="Time [s]",
    ylabel="a_z [m/s^2]",
    title="z Acceleration: Command vs Achieved",
    linewidth=3,
    color=:blue,
    grid=true,
    ylims=(-10.0, 10.0),
)
plot!(p_cmd_z, t_vec, achieved_accel_hist[2, :], label="a_z achieved", linewidth=2.5, color=:orange, linestyle=:dash)
# hline!(p_cmd_z, [-100.0, 100.0], label=false, linestyle=:dot, color=:black, linewidth=1.5)

plot(p_cmd_x, p_cmd_z, layout=(2, 1), size=(1100, 700))

# %%
using LaTeXStrings

rear_prop_degrade = [VTOL.rear_prop_degradation(sol(t), u_hist[:,i])/u_hist[3,i]^2 for (i,t) in enumerate(t_vec)]
labels = [L"C_{D_e}", L"C_{D_\alpha}", L"C_{D_t}", L"C_{L_e}", L"C_{L_\alpha}", L"C_{M_e}", L"C_{M_\alpha}", L"C_{M_\omega}", L"C_{pr}"]
palette = distinguishable_colors(length(labels))
plot()
for i in 1:n_W-1
    plot!(t_vec, abs.(W_hist[i,:] .- W_true[i]), label=labels[i], linewidth=2, color=palette[i])
end
plot!(t_vec, abs.(W_hist[end,:] - rear_prop_degrade), label=labels[end], linewidth=2, color=palette[end])
plot!(legend=true, legend_columns=3,ylims=(0,3), xtickfontsize=14, ytickfontsize=14, legendfontsize=14, xlabel="Time [s]", ylabel="Parameter Error")

# %%
tracking_error_x = [sol(t)[1] - ref_pose(t, traj)[1] for t in t_vec]
tracking_error_y = [sol(t)[2] - ref_pose(t, traj)[2] for t in t_vec]
tracking_error_pitch = [sol(t)[3] for t in t_vec] - u_hist[5,:] # pitch command
palette = distinguishable_colors(5)[3:end]
plot(t_vec, tracking_error_x, 
xlabel="Time [s]", ylabel="Tracking Error [m]", title="Tracking Error",
 color = palette[1], label ="p_x err", ylim=(-3.5,3.5), legend=:topleft, linewidth=4, grid=true)
plot!(t_vec, tracking_error_y, color = palette[2], label="p_z err", linewidth=4)
plot!(twinx(), t_vec, 180/pi*tracking_error_pitch, color = palette[3], label="pitch err", ylim=(-3.5,3.5), grid=true, legend=:topright, linewidth=4, ylabel="Tracking Error [deg]")

# %%
plot(t_vec, FOO_vec', label=["∂L/∂u₁" "∂L/∂u₂" "∂L/∂u₃" "∂L/∂u₄" "∂L/∂u₅" "∂L/∂λ₁" "∂L/∂λ₂" "∂L/∂λ₃"],
     xlabel="Time [s]", ylabel="Gradient of Lagrangian",
     title="Gradient of Lagrangian Evolution", ylim=(-1, 1), linewidth=2)

# %%
plot(t_vec, norm_e_s_vec, xlabel="Time [s]", ylabel="||e_s||",
     title="State Estimation Error Norm", ylim=(0, 2.0),legend=false, linewidth=2)

# %%
# Benchmark helper: run one scenario with either adaptive or non-adaptive PID inner loop
function run_controller_case(
    controller_mode::Symbol,
    scenario::Symbol;
    x0_init=x0_initial,
    u_init=u_initial,
    λ_init=λ_initial,
    W_init=W_initial,
    xhat_init=xhat0_initial,
)

    sim = SimulationParams(high_level=scenario_high_level_params(scenario))
    traj = sim.high_level.ref_traj

    x0_case = copy(x0_init)
    u0_case = copy(u_init)
    λ0_case = copy(λ_init)
    W0_case = copy(W_init)
    xhat0_case = copy(xhat_init)

    allocator_cb = controller_mode == :adaptive ? adaptive_control_allocator! : cascaded_pid_allocator!
    cb = PeriodicCallback(allocator_cb, sim.dt; initial_affect=true)

    data = SimulationData(u=u0_case, λ=λ0_case, W=W0_case, xhat=xhat0_case, params=sim)
    prob = ODEProblem(dudt!, copy(x0_case), (sim.t0, sim.t_final), data)
    sol = solve(prob, Tsit5(), callback=cb)

    t_vec = data.t_hist

    cmd_hist = zeros(n_λ, length(t_vec))

    achieved_accel_hist = zeros(2, length(t_vec))
    for (i, t) in enumerate(t_vec)
        if t <= sol.t[end]
            x_i = sol(t)
            u_i = data.u_hist[i]
            xhat_i = data.xhat_hist[i]
            if all(isfinite, x_i) && all(isfinite, u_i) && all(isfinite, xhat_i)
                cmd_hist[:,i] = high_level_control(t, x_i, u_i, xhat_i, sim.high_level, sim.adaptation)
            else
                cmd_hist[:,i] .= NaN
            end

            if all(isfinite, x_i) && all(isfinite, u_i)

                achieved_accel_hist[:,i] = VTOL.dynamics_sim(x_i, u_i, sim.vtol)[4:5]

            else

                achieved_accel_hist[:,i] .= NaN

            end
        else
            cmd_hist[:,i] .= NaN

            achieved_accel_hist[:,i] .= NaN
        end
    end
    x_hist = [t <= sol.t[end] ? sol(t) : fill(NaN, n_x) for t in t_vec]

    tracking_error_x = [x_hist[i][1] - ref_pose(t, traj)[1] for (i, t) in enumerate(t_vec)]

    tracking_error_z = [x_hist[i][2] - ref_pose(t, traj)[2] for (i, t) in enumerate(t_vec)]

    tracking_error_pitch = [x_hist[i][3] - data.u_hist[i][5] for (i, t) in enumerate(t_vec)]

    return (
        mode=controller_mode,
        scenario=scenario,
        sim=sim,
        traj=traj,
        sol=sol,
        data=data,
        t_vec=t_vec,

        cmd_hist=cmd_hist,

        achieved_accel_hist=achieved_accel_hist,
        err_x=tracking_error_x,
        err_z=tracking_error_z,
        err_pitch=tracking_error_pitch,
    )
end

benchmark_scenario = scenario  # reuse the scenario from the top setup cell
adaptive_case = run_controller_case(:adaptive, benchmark_scenario)
pid_case = run_controller_case(:pid_benchmark, benchmark_scenario)

# %%
# Side-by-side tracking error comparison: adaptive vs PID benchmark
p_x = plot(
    adaptive_case.t_vec, adaptive_case.err_x,
    label="adaptive", linewidth=3, color=:blue,
    xlabel="Time [s]", ylabel="p_x error [m]", title="Tracking Error in p_x",
    grid=true,
 )
plot!(p_x, pid_case.t_vec, pid_case.err_x, label="pid benchmark", linewidth=3, color=:red, linestyle=:dash)

p_z = plot(
    adaptive_case.t_vec, adaptive_case.err_z,
    label="adaptive", linewidth=3, color=:blue,
    xlabel="Time [s]", ylabel="p_z error [m]", title="Tracking Error in p_z",
    grid=true,
 )
plot!(p_z, pid_case.t_vec, pid_case.err_z, label="pid benchmark", linewidth=3, color=:red, linestyle=:dash)

p_theta = plot(
    adaptive_case.t_vec, 180/pi .* adaptive_case.err_pitch,
    label="adaptive", linewidth=3, color=:blue,
    xlabel="Time [s]", ylabel="pitch error [deg]", title="Tracking Error in Pitch",
    grid=true,
 )
plot!(p_theta, pid_case.t_vec, 180/pi .* pid_case.err_pitch, label="pid benchmark", linewidth=3, color=:red, linestyle=:dash)

plot(p_x, p_z, p_theta, layout=(3, 1), size=(1200, 900))

# %%
# Side-by-side commanded and achieved acceleration comparison
p_ax_cmd = plot(
    adaptive_case.t_vec, adaptive_case.cmd_hist[1, :],
    label="adaptive cmd", linewidth=3, color=:blue,
    xlabel="Time [s]", ylabel="a_x [m/s^2]", title="x Acceleration: Command vs Achieved",
    grid=true,
)
plot!(p_ax_cmd, adaptive_case.t_vec, adaptive_case.achieved_accel_hist[1, :], label="adaptive achieved", linewidth=2.5, color=:blue, linestyle=:dash)
plot!(p_ax_cmd, pid_case.t_vec, pid_case.cmd_hist[1, :], label="pid cmd", linewidth=3, color=:red)
plot!(p_ax_cmd, pid_case.t_vec, pid_case.achieved_accel_hist[1, :], label="pid achieved", linewidth=2.5, color=:red, linestyle=:dash)
hline!(p_ax_cmd, [-2.0, 3.0], label=false, linestyle=:dot, color=:black, linewidth=1.5)

p_az_cmd = plot(
    adaptive_case.t_vec, adaptive_case.cmd_hist[2, :],
    label="adaptive cmd", linewidth=3, color=:blue,
    xlabel="Time [s]", ylabel="a_z [m/s^2]", title="z Acceleration: Command vs Achieved",
    grid=true,
    ylims=(-10.0, 10.0),
)
plot!(p_az_cmd, adaptive_case.t_vec, adaptive_case.achieved_accel_hist[2, :], label="adaptive achieved", linewidth=2.5, color=:blue, linestyle=:dash)
plot!(p_az_cmd, pid_case.t_vec, pid_case.cmd_hist[2, :], label="pid cmd", linewidth=3, color=:red)
plot!(p_az_cmd, pid_case.t_vec, pid_case.achieved_accel_hist[2, :], label="pid achieved", linewidth=2.5, color=:red, linestyle=:dash)
# hline!(p_az_cmd, [-100.0, 100.0], label=false, linestyle=:dot, color=:black, linewidth=1.5)

plot(p_ax_cmd, p_az_cmd, layout=(2, 1), size=(1200, 750))

# %%
# # Animate adaptive and PID landing simultaneously
# include("animation.jl")
# animate_vtol_comparison(
#     adaptive_case,
#     pid_case,
#     t -> ref_pose(t, adaptive_case.traj);
#     fps=15,
#     filename="vtol_landing_adaptive_vs_pid.gif",
# )
